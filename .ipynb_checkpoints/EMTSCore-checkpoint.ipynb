# %%
import sys
print(sys.executable)

# %%
import pandas as pd
import pyreadr
import requests
from pathlib import path
import importlib
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 import pyreadr
#       3 import requests
#       4 from pathlib import path
#
# ModuleNotFoundError: No module named 'pyreadr'

# %% [markdown]
# # Checking cell annotation path

# %%
cell_annotation_path = Path("data/cell_annotation_file.csv") 
cell_annot = pd.read_csv(cell_annotation_path)
cell_annot.head()  # preview first 5 rows
